# %%
from server_utils import ask_llm_with_redis_smart, load_application_data
import time

# %%
# 1234567892 est une simulation de ID request d'application Application_Recette
app_id = 1234567890
load_application_data(app_id=app_id)
# Out:
# True

# %%
start = time.time()
user_query = "donner moi deux quizzes sur surat al baqara"
res, from_cache = ask_llm_with_redis_smart(user_query, app_id=app_id)
print(user_query)
print(res)
print("Cache:", from_cache)
print("Temps:", time.time() - start)
# Out:
# donner moi deux quizzes sur surat al baqara
# Désolé, je suis uniquement un assistant de cuisine expert et je ne peux répondre qu'aux questions liées aux recettes et à la cuisine. Puis-je vous aider avec une recette ou une technique culinaire ?
# Cache: False
# Temps: 1.6164169311523438

# %%
start = time.time()
user_query = "donne moi en resumer l'histoire de prophet mohamed"
res, from_cache = ask_llm_with_redis_smart(user_query, app_id=app_id)
print(user_query)
print(res)
print("Cache:", from_cache)
print("Temps:", time.time() - start)
# Out:
# donne moi en resumer l'histoire de prophet mohamed
# Désolé, je suis uniquement un assistant de cuisine expert et je ne peux répondre qu'aux questions liées aux recettes et à la cuisine. Puis-je vous aider avec une recette ou une technique culinaire ?
# Cache: False
# Temps: 3.37213134765625

# %%
start = time.time()
user_query = "can you tell me about moroccan food, if i have potato as principal ingredient"
res, from_cache = ask_llm_with_redis_smart(user_query, app_id=app_id)
print(user_query)
print(res)
print("Cache:", from_cache)
print("Temps:", time.time() - start)
# Out:
# can you tell me about moroccan food, if i have potato as principal ingredient
# Oui, les pommes de terre sont un ingrédient courant et apprécié dans la cuisine marocaine, où elles sont souvent utilisées comme ingrédient principal dans diverses préparations.
#
# Par exemple, nous avons la recette de la **Salade de pommes de terre épicée d'Afrique du Nord (Marocain végétarien)**. Dans ce plat, les pommes de terre sont l'ingrédient vedette. Elles sont bouillies jusqu'à ce qu'elles soient tendres, puis mélangées à une sauce piquante à base d'épices harissa, d'huile d'olive et de jus de citron. Des oignons nouveaux sont ajoutés, et la salade est ensuite servie sur un lit de roquette, garnie de feta, de menthe fraîche et de pignons de pin. C'est une salade savoureuse, souvent consommée froide ou tiède.
#
# En dehors de cette salade, les pommes de terre sont également intégrées dans d'autres plats marocains comme des tajines (ragoûts) où elles absorbent les saveurs riches des épices et des légumes, ou encore dans des soupes et des accompagnements.
# Cache: False
# Temps: 10.104157209396362
